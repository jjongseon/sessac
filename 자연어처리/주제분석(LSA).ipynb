# %% [markdown]
# ## 전처리
# * neur IPS(신경 정보 처리 학회 : + 생물학적 신경 정보 + 머신러닝)
# * 2007~2017

# %%
import pandas as pd
df = pd.read_csv('neurips.zip')
df.head()
# Out:
#    year                                              title  \
# 0  2007                        Competition Adds Complexity
# 1  2007  Efficient Principled Learning of Thin Junction...
# 2  2007     Regularized Boost for Semi-Supervised Learning
# 3  2007  Simplified Rules and Theoretical Analysis for ...
# 4  2007  Predicting human gaze using low-level saliency...
#
#                                             abstract
# 0  It is known that determinining whether a DEC-P...
# 1  We present the first truly polynomial algorith...
# 2  Semi-supervised inductive learning concerns ho...
# 3  We show that under suitable assumptions (prima...
# 4  Under natural viewing conditions, human observ...

# %%
df.tail()
# Out:
#       year                                              title  \
# 3915  2017  On Separability of Loss Functions, and Revisit...
# 3916  2017            Maxing and Ranking with Few Assumptions
# 3917  2017                  On clustering network-valued data
# 3918  2017  A General Framework for Robust Interactive Lea...
# 3919  2017  Multi-view Matrix Factorization for Linear Dyn...
#
#                                                abstract
# 3915  We revisit the classical analysis of generativ...
# 3916  PAC maximum                                   ...
# 3917  Community detection, which focuses on clusteri...
# 3918  We propose a general framework for interactive...
# 3919  We consider maximum likelihood estimation of l...

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
cv = TfidfVectorizer(stop_words='english', max_features=2000)

# %%
x = cv.fit_transform(df.abstract)

# %%
words = cv.get_feature_names()
words
# Out:
# c:\Users\seon\.conda\envs\myenv\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['000',
#  '10',
#  '100',
#  '20',
#  '2d',
#  '3d',
#  'ability',
#  'able',
#  'absolute',
#  'abstract',
#  'accelerated',
#  'access',
#  'according',
#  'account',
#  'accounts',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'achieve',
#  'achieved',
#  'achieves',
#  'achieving',
#  'action',
#  'actions',
#  'activation',
#  'activations',
#  'active',
#  'activities',
#  'activity',
#  'actor',
#  'actually',
#  'ad',
#  'adapt',
#  'adaptation',
#  'adapted',
#  'adaptive',
#  'adaptively',
#  'addition',
#  'additional',
#  'additionally',
#  'additive',
#  'address',
#  'addressed',
#  'addresses',
#  'admits',
#  'admm',
#  'advances',
#  'advantage',
#  'advantages',
#  'adversarial',
#  'adversary',
#  'affine',
#  'affinity',
#  'agent',
#  'agents',
#  'aggregation',
#  'agnostic',
#  'aim',
#  'aims',
#  'al',
#  'algorithm',
#  'algorithmic',
#  'algorithms',
#  'alignment',
#  'allocation',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'alpha',
#  'alternating',
#  'alternative',
#  'alternatives',
#  'amounts',
#  'analyses',
#  'analysis',
#  'analytic',
#  'analytical',
#  'analytically',
#  'analyze',
#  'analyzing',
#  'animals',
#  'annotations',
#  'answer',
#  'appearance',
#  'applicability',
#  'applicable',
#  'application',
#  'applications',
#  'applied',
#  'applies',
#  'apply',
#  'applying',
#  'approach',
#  'approaches',
#  'appropriate',
#  'approximate',
#  'approximated',
#  'approximately',
#  'approximates',
#  'approximating',
#  'approximation',
#  'approximations',
#  'arbitrarily',
#  'arbitrary',
#  'architecture',
#  'architectures',
#  'area',
#  'areas',
#  'argue',
#  'arise',
#  'arises',
#  'arising',
#  'arm',
#  'armed',
#  'arms',
#  'art',
#  'artificial',
#  'ascent',
#  'aspects',
#  'assignment',
#  'associated',
#  'assume',
#  'assumed',
#  'assumes',
#  'assuming',
#  'assumption',
#  'assumptions',
#  'asymptotic',
#  'asymptotically',
#  'asynchronous',
#  'atoms',
#  'attempt',
#  'attempts',
#  'attention',
#  'attractive',
#  'attribute',
#  'attributes',
#  'audio',
#  'augmented',
#  'auto',
#  'autoencoder',
#  'automated',
#  'automatic',
#  'automatically',
#  'auxiliary',
#  'available',
#  'average',
#  'averaging',
#  'avoid',
#  'avoids',
#  'background',
#  'backpropagation',
#  'backward',
#  'bag',
#  'balance',
#  'bandit',
#  'bandits',
#  'base',
#  'based',
#  'baseline',
#  'baselines',
#  'bases',
#  'basic',
#  'basis',
#  'batch',
#  'bayes',
#  'bayesian',
#  'behavior',
#  'behavioral',
#  'behaviors',
#  'belief',
#  'beliefs',
#  'bellman',
#  'benchmark',
#  'benchmarks',
#  'benefit',
#  'benefits',
#  'best',
#  'beta',
#  'better',
#  'bias',
#  'biased',
#  'biases',
#  'big',
#  'binary',
#  'biological',
#  'biologically',
#  'bipartite',
#  'bit',
#  'bits',
#  'black',
#  'blind',
#  'block',
#  'blocks',
#  'body',
#  'boltzmann',
#  'boosting',
#  'bottleneck',
#  'bound',
#  'boundary',
#  'bounded',
#  'bounding',
#  'bounds',
#  'box',
#  'bp',
#  'brain',
#  'bregman',
#  'broad',
#  'broader',
#  'budget',
#  'build',
#  'building',
#  'builds',
#  'built',
#  'calcium',
#  'calibrated',
#  'called',
#  'camera',
#  'candidate',
#  'canonical',
#  'capable',
#  'capacity',
#  'capture',
#  'captures',
#  'capturing',
#  'cardinality',
#  'carefully',
#  'carlo',
#  'cascade',
#  'case',
#  'cases',
#  'cast',
#  'categories',
#  'categorization',
#  'category',
#  'causal',
#  'cell',
#  'cells',
#  'center',
#  'central',
#  'certain',
#  'chain',
#  'chains',
#  'challenge',
#  'challenges',
#  'challenging',
#  'change',
#  'changes',
#  'changing',
#  'characteristic',
#  'characteristics',
#  'characterization',
#  'characterize',
#  'characterized',
#  'characterizing',
#  'choice',
#  'choices',
#  'choose',
#  'choosing',
#  'chosen',
#  'cifar',
#  'circuit',
#  'circuits',
#  'cite',
#  'class',
#  'classes',
#  'classic',
#  'classical',
#  'classification',
#  'classifier',
#  'classifiers',
#  'clear',
#  'clinical',
#  'close',
#  'closed',
#  'closely',
#  'cluster',
#  'clustering',
#  'clusters',
#  'cnn',
#  'cnns',
#  'code',
#  'codes',
#  'coding',
#  'coefficient',
#  'coefficients',
#  'cognitive',
#  'coherent',
#  'collaborative',
#  'collected',
#  'collection',
#  'color',
#  'column',
#  'columns',
#  'combination',
#  'combinations',
#  'combinatorial',
#  'combine',
#  'combined',
#  'combines',
#  'combining',
#  'comes',
#  'common',
#  'commonly',
#  'communication',
#  'communities',
#  'community',
#  'compact',
#  'comparable',
#  'compare',
#  'compared',
#  'comparing',
#  'comparison',
#  'comparisons',
#  'competing',
#  'competitive',
#  'complete',
#  'completely',
#  'completion',
#  'complex',
#  'complexity',
#  'complicated',
#  'component',
#  'components',
#  'composite',
#  'compressed',
#  'compression',
#  'compressive',
#  'computation',
#  'computational',
#  'computationally',
#  'computations',
#  'compute',
#  'computed',
#  'computer',
#  'computes',
#  'computing',
#  'concave',
#  'concentration',
#  'concept',
#  'concepts',
#  'condition',
#  'conditional',
#  'conditioned',
#  'conditioning',
#  'conditions',
#  'conduct',
#  'confidence',
#  'confirm',
#  'conjugate',
#  'connected',
#  'connection',
#  'connections',
#  'connectivity',
#  'consequence',
#  'consequently',
#  'consider',
#  'considerable',
#  'considerably',
#  'considered',
#  'considering',
#  'considers',
#  'consistency',
#  'consistent',
#  'consistently',
#  'consisting',
#  'consists',
#  'constant',
#  'constrained',
#  'constraint',
#  'constraints',
#  'construct',
#  'constructed',
#  'constructing',
#  'construction',
#  'contain',
#  'containing',
#  'contains',
#  'content',
#  'context',
#  'contexts',
#  'contextual',
#  'continuous',
#  'contrast',
#  'contribution',
#  'contributions',
#  'control',
#  'controlled',
#  'conventional',
#  'converge',
#  'convergence',
#  'convergent',
#  'converges',
#  'convex',
#  'convexity',
#  'convolution',
#  'convolutional',
#  'coordinate',
#  'copula',
#  'core',
#  'correct',
#  'correlated',
#  'correlation',
#  'correlations',
#  'correspondence',
#  'corresponding',
#  'corresponds',
#  'corrupted',
#  'cortex',
#  'cortical',
#  'cost',
#  'costs',
#  'count',
#  'counterparts',
#  'counts',
#  'coupled',
#  'coupling',
#  'covariance',
#  'covariates',
#  'cover',
#  'criteria',
#  'criterion',
#  'critic',
#  'critical',
#  'cross',
#  'crowdsourcing',
#  'crucial',
#  'cs',
#  'cues',
#  'cumulative',
#  'current',
#  'currently',
#  'curvature',
#  'curve',
#  'curves',
#  'cut',
#  'data',
#  'database',
#  'databases',
#  'dataset',
#  'datasets',
#  'deal',
#  'decay',
#  'decision',
#  'decisions',
#  'decoder',
#  'decoding',
#  'decomposable',
#  'decomposition',
#  'deep',
#  'define',
#  'defined',
#  'defining',
#  'definite',
#  'definition',
#  'degree',
#  'delta',
#  'demonstrate',
#  'demonstrated',
#  'demonstrates',
#  'demonstrating',
#  'demonstrations',
#  'denoising',
#  'dense',
#  'densities',
#  'density',
#  'depend',
#  'dependence',
#  'dependencies',
#  'dependency',
#  'dependent',
#  'depending',
#  'depends',
#  'depth',
#  'derive',
#  'derived',
#  'deriving',
#  'descent',
#  'described',
#  'describes',
#  'describing',
#  'design',
#  'designed',
#  'designing',
#  'desirable',
#  'desired',
#  'despite',
#  'detailed',
#  'detect',
#  'detecting',
#  'detection',
#  'detectors',
#  'determine',
#  'determined',
#  'determining',
#  'deterministic',
#  'develop',
#  'developed',
#  'developing',
#  'development',
#  'devise',
#  'dictionary',
#  'difference',
#  'differences',
#  'different',
#  'differentiable',
#  'differential',
#  'difficult',
#  'difficulty',
#  'diffusion',
#  'dimension',
#  'dimensional',
#  'dimensionality',
#  'dimensions',
#  'direct',
#  'directed',
#  'direction',
#  'directions',
#  'directly',
#  'dirichlet',
#  'discover',
#  'discovering',
#  'discovery',
#  'discrepancy',
#  'discrete',
#  'discrimination',
#  'discriminative',
#  'discuss',
#  'disease',
#  'distance',
#  'distances',
#  'distinct',
#  'distributed',
#  'distribution',
#  'distributions',
#  'divergence',
#  'divergences',
#  'diverse',
#  'diversity',
#  'document',
#  'documents',
#  'does',
#  'domain',
#  'domains',
#  'dramatically',
#  'drawn',
#  'driven',
#  'dropout',
#  'dual',
#  'dynamic',
#  'dynamical',
#  'dynamically',
#  'dynamics',
#  'early',
#  'easier',
#  'easily',
#  'easy',
#  'edge',
#  'edges',
#  'eeg',
#  'effect',
#  'effective',
#  'effectively',
#  'effectiveness',
#  'effects',
#  'efficacy',
#  'efficiency',
#  'efficient',
#  'efficiently',
#  'effort',
#  'eigenvectors',
#  'elements',
#  'ell_1',
#  'em',
#  'embedded',
#  'embedding',
#  'embeddings',
#  'emph',
#  'empirical',
#  'empirically',
#  'employ',
#  'employed',
#  'employing',
#  'enable',
#  'enables',
#  'enabling',
#  'encode',
#  'encoded',
#  'encoder',
#  'encoding',
#  'end',
#  'energy',
#  'enjoys',
#  'ensemble',
#  'ensure',
#  'entire',
#  'entities',
#  'entries',
#  'entropy',
#  'environment',
#  'environments',
#  'ep',
#  'eps',
#  'epsilon',
#  'equal',
#  'equation',
#  'equations',
#  'equilibrium',
#  'equivalence',
#  'equivalent',
#  'erm',
#  'error',
#  'errors',
#  'especially',
#  'essential',
#  'essentially',
#  'establish',
#  'established',
#  'estimate',
#  'estimated',
#  'estimates',
#  'estimating',
#  'estimation',
#  'estimator',
#  'estimators',
#  'et',
#  'euclidean',
#  'evaluate',
#  'evaluated',
#  'evaluating',
#  'evaluation',
#  'evaluations',
#  'event',
#  'events',
#  'evidence',
#  'exact',
#  'exactly',
#  'examine',
#  'example',
#  'examples',
#  'excellent',
#  'exhibit',
#  'exhibits',
#  'exist',
#  'existence',
#  'existing',
#  'exists',
#  'expansion',
#  'expectation',
#  'expected',
#  'expensive',
#  'experience',
#  'experiment',
#  'experimental',
#  'experimentally',
#  'experiments',
#  'expert',
#  'experts',
#  'explain',
#  'explicit',
#  'explicitly',
#  'exploit',
#  'exploitation',
#  'exploiting',
#  'exploits',
#  'exploration',
#  'explore',
#  'explored',
#  'exponential',
#  'exponentially',
#  'expressed',
#  'expression',
#  'expressive',
#  'extend',
#  'extended',
#  'extending',
#  'extends',
#  'extension',
#  'extensions',
#  'extensive',
#  'extensively',
#  'external',
#  'extract',
#  'extracted',
#  'extracting',
#  'extraction',
#  'extreme',
#  'extremely',
#  'face',
#  'faces',
#  'fact',
#  'factor',
#  'factorization',
#  'factors',
#  'fail',
#  'fairness',
#  'false',
#  'families',
#  'family',
#  'far',
#  'fashion',
#  'fast',
#  'faster',
#  'favorable',
#  'feasible',
#  'feature',
#  'features',
#  'feed',
#  'feedback',
#  'feedforward',
#  'fewer',
#  'field',
#  'fields',
#  'filter',
#  'filtering',
#  'filters',
#  'final',
#  'finally',
#  'finding',
#  'findings',
#  'finds',
#  'fine',
#  'finite',
#  'firing',
#  'fisher',
#  'fit',
#  'fitting',
#  'fixed',
#  'flexibility',
#  'flexible',
#  'flow',
#  'fmri',
#  'focus',
#  'focused',
#  'focuses',
#  'focusing',
#  'follow',
#  'followed',
#  'following',
#  'follows',
#  'form',
#  'formal',
#  'formalize',
#  'forms',
#  'formulate',
#  'formulated',
#  'formulation',
#  'formulations',
#  'forward',
#  'frac',
#  'fraction',
#  'frame',
#  'frames',
#  'framework',
#  'free',
#  'frequency',
#  'fully',
#  'function',
#  'functional',
#  'functions',
#  'fundamental',
#  'furthermore',
#  'future',
#  'gain',
#  'gained',
#  'gains',
#  'game',
#  'games',
#  'gamma',
#  'gan',
#  'gans',
#  'gap',
#  'gaussian',
#  'gene',
#  'general',
#  'generalization',
#  'generalize',
#  'generalized',
#  'generalizes',
#  'generalizing',
#  'generally',
#  'generate',
#  'generated',
#  'generates',
#  'generating',
#  'generation',
#  'generative',
#  'generator',
#  'generic',
#  'geometric',
#  'geometry',
#  'gibbs',
#  'given',
#  'gives',
#  'global',
#  'globally',
#  'goal',
#  'goals',
#  'good',
#  'gp',
#  'gps',
#  'gradient',
#  'gradients',
#  'graph',
#  'graphical',
#  'graphs',
#  'great',
#  'greater',
#  'greatly',
#  'greedy',
#  'grid',
#  'ground',
#  'group',
#  'groups',
#  'growing',
#  'grows',
#  'guarantee',
#  'guaranteed',
#  'guarantees',
#  'guided',
#  'hand',
#  'handle',
#  'handling',
#  'hard',
#  'hash',
#  'hashing',
#  'having',
#  'heavy',
#  'help',
#  'hessian',
#  'heterogeneous',
#  'heuristic',
#  'heuristics',
#  'hidden',
#  'hierarchical',
#  'hierarchy',
#  'high',
#  'higher',
#  'highly',
#  'hilbert',
#  'hinge',
#  'history',
#  'hold',
#  'holds',
#  'horizon',
#  'human',
#  'humans',
#  'hundreds',
#  'hybrid',
#  'hyperparameter',
#  'hyperparameters',
#  'hypotheses',
#  'hypothesis',
#  'ica',
#  'idea',
#  'ideal',
#  'ideas',
#  'identifiability',
#  'identification',
#  'identified',
#  'identify',
#  'identifying',
#  'ii',
#  'iii',
#  'illustrate',
#  'image',
#  'imagenet',
#  'images',
#  'imaging',
#  'impact',
#  'implement',
#  'implementation',
#  'implementations',
#  'implemented',
#  'implicit',
#  'implicitly',
#  'implies',
#  'importance',
#  'important',
#  'importantly',
#  'improve',
#  'improved',
#  'improvement',
#  'improvements',
#  'improves',
#  'improving',
#  'include',
#  'includes',
#  'including',
#  'incomplete',
#  'incorporate',
#  'incorporates',
#  'incorporating',
#  'increase',
#  'increases',
#  'increasing',
#  'increasingly',
#  'incremental',
#  'independence',
#  'independent',
#  'independently',
#  'index',
#  'indicate',
#  'individual',
#  'individuals',
#  'induced',
#  'inducing',
#  'inequalities',
#  'inequality',
#  'infer',
#  'inference',
#  'inferences',
#  'inferred',
#  'inferring',
#  'infinite',
#  'influence',
#  'information',
#  'informative',
#  'infty',
#  'inherent',
#  'initial',
#  'initialization',
#  'inner',
#  'input',
#  'inputs',
#  'insight',
#  'insights',
#  'inspired',
#  'instance',
#  'instances',
#  'instead',
#  'integer',
#  'integrate',
#  'integrated',
#  'integrates',
#  'integration',
#  'inter',
#  'interact',
#  'interaction',
#  'interactions',
#  'interested',
#  'interesting',
#  'interestingly',
#  'intermediate',
#  'internal',
#  'interpret',
#  'interpretability',
#  'interpretable',
#  'interpretation',
#  'interpreted',
#  'intervals',
#  'intractable',
#  'intrinsic',
#  'introduce',
#  'introduced',
#  'introduces',
#  'introducing',
#  'intuitive',
#  'invariance',
#  'invariant',
#  'inverse',
#  'investigate',
#  'involve',
#  'involves',
#  'involving',
#  'ising',
#  'issue',
#  'issues',
#  'item',
#  'items',
#  'iteration',
#  'iterations',
#  'iterative',
#  'iteratively',
#  'joint',
#  'jointly',
#  'just',
#  'kernel',
#  'kernels',
#  'key',
#  'kind',
#  'kl',
#  'knowledge',
#  'known',
#  'l1',
#  'l2',
#  'label',
#  'labeled',
#  'labeling',
#  'labels',
#  'lack',
#  'lambda',
#  'language',
#  'laplacian',
#  'large',
#  'largely',
#  'larger',
#  'lasso',
#  'latent',
#  ...]

# %% [markdown]
# ## SVD

# %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=100, random_state=1234)

# %%
x.shape
# Out:
# (3920, 2000)

# %%
# fit : 일종의 분석하는 과정
# transform : 분석 결과를 바탕으로 변환한 후 새로운 뭔가를 만들어 내는 과정

# 결과1 : 문서가 차원(100)과 어떤 관계에 있나?
# 결과2 : 단어가 차원(100)과 어떤 관계에 있나?

svd.fit(x)
# Out:
# TruncatedSVD(n_components=100, random_state=1234)

# %%
# 결과2 : 차원과 단어가 어떤 관계에 있느냐?
svd.components_.shape
# Out:
# (100, 2000)

# %%
# ex) 0.00483864 - 1차원의 값이 1 증가하면 단어가 0.0048만큼 증가를 함
# 0.00483864 : 1차원 1000정도 증가하면 단어가 5개가 더 많이 쓰임
svd.components_
# Out:
# array([[ 0.00483864,  0.01243762,  0.004755  , ...,  0.00491457,
#          0.0162017 ,  0.01160996],
#        [-0.0055402 , -0.01859974, -0.00681511, ...,  0.00074343,
#          0.0014955 ,  0.00839796],
#        [-0.00331551, -0.02285996, -0.00537686, ..., -0.00103497,
#          0.00135762, -0.00786135],
#        ...,
#        [-0.00037104,  0.02843677,  0.00591093, ...,  0.0027189 ,
#          0.01184353, -0.01022713],
#        [ 0.00286079, -0.02232737, -0.00742612, ...,  0.00374566,
#         -0.00553911, -0.00644252],
#        [ 0.00840489,  0.00073834,  0.00954845, ..., -0.00397496,
#         -0.00763423, -0.00401217]])

# %%
len(svd.components_)
# Out:
# 100

# %%
word_idx = words.index('topic')
word_idx
# Out:
# 1861

# %%
# 마이너스 값의 의미는 topic와 주제가 강해질수록 이 단어는 덜 쓰임
svd.components_[:, word_idx]
# Out:
# array([ 2.21636837e-02, -3.35006049e-02,  6.34481186e-02, -9.08255574e-03,
#        -2.59052356e-02, -3.04093871e-02,  4.31240860e-02, -4.44698174e-02,
#        -5.35017435e-02,  2.51650395e-02, -7.43829615e-02, -4.09887607e-02,
#         1.43222364e-03,  9.13531186e-02, -5.15778667e-02,  1.43561806e-02,
#         1.43079857e-02,  1.08711712e-01, -1.99153193e-02,  9.44076667e-02,
#        -1.49543745e-01,  7.67068611e-02, -9.41560593e-02,  1.36303047e-02,
#        -4.61174101e-02,  1.04014531e-01,  1.14117206e-01,  1.99617317e-01,
#         3.19722162e-02,  6.47920314e-02, -9.24920865e-02,  2.24452596e-02,
#         1.25802356e-02,  1.57600255e-02,  3.03693389e-02, -1.57972126e-01,
#        -6.85859397e-02, -2.71583590e-02, -4.23475068e-02,  6.59471303e-03,
#        -7.82198356e-02,  6.56273694e-02,  1.66759836e-02,  5.84677258e-02,
#         1.36793675e-02, -4.11903979e-02,  2.94849115e-02, -2.23744287e-02,
#        -7.98992089e-02,  7.03076161e-02, -8.41267895e-02, -9.61470800e-02,
#        -6.79298440e-02, -5.14578997e-02,  1.18931180e-02,  6.15789682e-03,
#        -1.11474880e-02,  2.94867952e-02, -3.66363896e-02, -1.41744462e-02,
#         7.36274594e-03, -2.46158653e-02,  6.47961771e-02,  8.95522624e-03,
#        -3.96913139e-04, -1.79853016e-04, -2.22553679e-02, -1.80523672e-02,
#        -1.10168346e-01, -4.43826153e-02,  4.81139312e-02,  1.52893745e-02,
#        -1.04502313e-02, -5.66792722e-02,  7.90153696e-03,  3.95921870e-02,
#        -3.68376423e-02, -1.54981663e-01,  3.38559085e-02, -1.33979470e-02,
#        -1.31676964e-02,  5.59717455e-02,  6.29342326e-03, -7.21399145e-02,
#        -3.23451854e-02, -5.00067057e-02,  3.33799447e-02, -4.32286199e-02,
#         1.07889200e-02, -5.35033227e-02,  1.78997607e-02, -8.99275159e-02,
#        -3.15281923e-02,  1.14875441e-02, -1.65870226e-02,  8.21166940e-02,
#        -2.44319766e-02,  1.91906063e-02,  5.36237310e-02,  4.61675260e-02])

# %%
len(svd.components_[:, word_idx])
# Out:
# 100

# %%
from matplotlib import pyplot

pyplot.plot(svd.components_[:, word_idx])

# %%
# "topic"이라는 단어와 가장 관련이 높은 주제
topic_idx = svd.components_[:, word_idx].argmax()
topic_idx
# Out:
# 27

# %%
# 주제 27이 다른 단어들하고 얼마나 관련이 있는지를 확인
topic = pd.DataFrame({'word': words, 'loading': svd.components_[topic_idx]})
topic.sort_values('loading').tail()
# Out:
#         word   loading
# 1202    norm  0.119621
# 804    graph  0.126101
# 866    image  0.155490
# 1861   topic  0.199617
# 1713  sparse  0.211411

# %% [markdown]
# ## 회전

# %%
# !pip install factor_analyzer
# Out:
# Collecting factor_analyzer
#   Downloading factor_analyzer-0.4.1.tar.gz (41 kB)
#      ---------------------------------------- 41.8/41.8 kB 2.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pre-commit
#   Downloading pre_commit-2.20.0-py2.py3-none-any.whl (199 kB)
#      -------------------------------------- 199.5/199.5 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in c:\users\seon\.conda\envs\myenv\lib\site-packages (from factor_analyzer) (1.0.2)
# Requirement already satisfied: pandas in c:\users\seon\.conda\envs\myenv\lib\site-packages (from factor_analyzer) (1.2.3)
# Requirement already satisfied: numpy in c:\users\seon\.conda\envs\myenv\lib\site-packages (from factor_analyzer) (1.21.6)
# Requirement already satisfied: scipy in c:\users\seon\.conda\envs\myenv\lib\site-packages (from factor_analyzer) (1.7.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\seon\.conda\envs\myenv\lib\site-packages (from pandas->factor_analyzer) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\seon\.conda\envs\myenv\lib\site-packages (from pandas->factor_analyzer) (2.8.2)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-win_amd64.whl (153 kB)
#      -------------------------------------- 153.2/153.2 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in c:\users\seon\.conda\envs\myenv\lib\site-packages (from pre-commit->factor_analyzer) (4.11.4)
# Collecting cfgv>=2.0.0
#   Downloading cfgv-3.3.1-py2.py3-none-any.whl (7.3 kB)
# Collecting virtualenv>=20.0.8
#   Downloading virtualenv-20.16.6-py3-none-any.whl (8.8 MB)
#      ---------------------------------------- 8.8/8.8 MB 11.3 MB/s eta 0:00:00
# Collecting identify>=1.0.0
#   Downloading identify-2.5.8-py2.py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.7/98.7 kB 5.5 MB/s eta 0:00:00
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting nodeenv>=0.11.1
#   Downloading nodeenv-1.7.0-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: joblib>=0.11 in c:\users\seon\.conda\envs\myenv\lib\site-packages (from scikit-learn->factor_analyzer) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\seon\.conda\envs\myenv\lib\site-packages (from scikit-learn->factor_analyzer) (3.1.0)
# Requirement already satisfied: setuptools in c:\users\seon\.conda\envs\myenv\lib\site-packages (from nodeenv>=0.11.1->pre-commit->factor_analyzer) (59.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\seon\.conda\envs\myenv\lib\site-packages (from python-dateutil>=2.7.3->pandas->factor_analyzer) (1.16.0)
# Collecting filelock<4,>=3.4.1
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ------------------------------------- 468.5/468.5 kB 14.8 MB/s eta 0:00:00
# Collecting platformdirs<3,>=2.4
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\seon\.conda\envs\myenv\lib\site-packages (from importlib-metadata->pre-commit->factor_analyzer) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\seon\.conda\envs\myenv\lib\site-packages (from importlib-metadata->pre-commit->factor_analyzer) (3.9.0)
# Building wheels for collected packages: factor_analyzer
#   Building wheel for factor_analyzer (pyproject.toml): started
#   Building wheel for factor_analyzer (pyproject.toml): finished with status 'done'
#   Created wheel for factor_analyzer: filename=factor_analyzer-0.4.1-py2.py3-none-any.whl size=42015 sha256=6d37e2e45debeeb30f43edac3903572c447d7d605292235f3d2c4b3ab9e91c16
#   Stored in directory: c:\users\seon\appdata\local\pip\cache\wheels\ed\90\48\766e09628cc5bbcf57c2eb063972c1e956a03422dd6d84fde2
# Successfully built factor_analyzer
# Installing collected packages: distlib, toml, pyyaml, platformdirs, nodeenv, identify, filelock, cfgv, virtualenv, pre-commit, factor_analyzer
# Successfully installed cfgv-3.3.1 distlib-0.3.6 factor_analyzer-0.4.1 filelock-3.8.0 identify-2.5.8 nodeenv-1.7.0 platformdirs-2.5.2 pre-commit-2.20.0 pyyaml-6.0 toml-0.10.2 virtualenv-20.16.6

# %%
from factor_analyzer.rotator import Rotator
rotator = Rotator()

# %%
svd.components_
# Out:
# array([[ 0.00483864,  0.01243762,  0.004755  , ...,  0.00491457,
#          0.0162017 ,  0.01160996],
#        [-0.0055402 , -0.01859974, -0.00681511, ...,  0.00074343,
#          0.0014955 ,  0.00839796],
#        [-0.00331551, -0.02285996, -0.00537686, ..., -0.00103497,
#          0.00135762, -0.00786135],
#        ...,
#        [-0.00037104,  0.02843677,  0.00591093, ...,  0.0027189 ,
#          0.01184353, -0.01022713],
#        [ 0.00286079, -0.02232737, -0.00742612, ...,  0.00374566,
#         -0.00553911, -0.00644252],
#        [ 0.00840489,  0.00073834,  0.00954845, ..., -0.00397496,
#         -0.00763423, -0.00401217]])

# %%
svd.components_.T
# Out:
# array([[ 0.00483864, -0.0055402 , -0.00331551, ..., -0.00037104,
#          0.00286079,  0.00840489],
#        [ 0.01243762, -0.01859974, -0.02285996, ...,  0.02843677,
#         -0.02232737,  0.00073834],
#        [ 0.004755  , -0.00681511, -0.00537686, ...,  0.00591093,
#         -0.00742612,  0.00954845],
#        ...,
#        [ 0.00491457,  0.00074343, -0.00103497, ...,  0.0027189 ,
#          0.00374566, -0.00397496],
#        [ 0.0162017 ,  0.0014955 ,  0.00135762, ...,  0.01184353,
#         -0.00553911, -0.00763423],
#        [ 0.01160996,  0.00839796, -0.00786135, ..., -0.01022713,
#         -0.00644252, -0.00401217]])

# %%
rot = rotator.fit_transform(svd.components_.T)

# %%
rot.shape
# Out:
# (2000, 100)

# %%
loading = rot.T
loading
# Out:
# array([[ 2.26031579e-03, -1.46141078e-02,  4.75134168e-03, ...,
#         -2.07869722e-03, -4.94782985e-03, -1.54189743e-02],
#        [-7.58446329e-05, -3.02516232e-02, -1.37841149e-02, ...,
#         -5.97268133e-03, -1.80146545e-02,  7.02248518e-04],
#        [ 2.15230776e-04,  6.41827152e-03, -2.10422460e-03, ...,
#         -2.92316535e-03,  1.08321415e-02, -1.09935220e-02],
#        ...,
#        [ 5.78489085e-03,  2.94497270e-03, -2.31205236e-03, ...,
#          4.93684998e-03,  8.47498284e-03, -5.82273250e-03],
#        [-2.87234211e-03, -5.36252472e-03, -4.55952569e-03, ...,
#         -9.71656996e-04,  1.07999669e-03, -6.56684273e-03],
#        [ 2.58919593e-03,  3.46739225e-03,  6.04591906e-04, ...,
#          7.44908419e-03,  4.40389483e-03, -5.95080180e-03]])

# %%
loading.shape
# Out:
# (100, 2000)

# %%
word_idx = words.index('topic')
word_idx
# Out:
# 1861

# %%
pyplot.plot(loading[:, word_idx])

# %%
topic_idx = loading[:, word_idx].argmax()
topic_idx
# Out:
# 27

# %%
topic = pd.DataFrame({'word': words, 'loading': loading[topic_idx]})
topic.sort_values('loading').tail(10)
# Out:
#            word   loading
# 1842       text  0.121777
# 999      latent  0.157819
# 520   dirichlet  0.187826
# 540    document  0.192213
# 1987       word  0.208114
# 1988      words  0.215588
# 1003        lda  0.224917
# 541   documents  0.225140
# 1862     topics  0.273106
# 1861      topic  0.566290

# %%
doc_topics = svd.transform(x)
doc_topics.shape
# Out:
# (3920, 100)

# %%
doc_topics
# Out:
# array([[ 8.26281390e-02,  7.63577154e-02, -4.10771349e-02, ...,
#         -5.53512216e-02,  1.92191685e-02,  6.58102255e-02],
#        [ 2.74179474e-01,  2.53724097e-02,  1.25862532e-01, ...,
#          5.81502666e-02,  5.09035674e-02, -1.13576542e-02],
#        [ 1.96016274e-01,  1.98015150e-04, -1.11449676e-01, ...,
#         -1.64795397e-02,  4.72946075e-02,  1.79354744e-02],
#        ...,
#        [ 1.90719150e-01, -8.92629352e-02, -3.90917871e-02, ...,
#         -4.44977239e-02,  3.06777292e-02, -2.04077917e-02],
#        [ 2.64942038e-01, -1.08470408e-02,  1.83582504e-03, ...,
#          7.71449997e-02, -5.24559385e-02,  5.72485006e-04],
#        [ 2.22241450e-01,  1.31254992e-02,  1.06533931e-01, ...,
#         -4.43651902e-02, -1.32319750e-02,  3.61840754e-02]])

# %%
doc_topics = doc_topics@  rotator.rotation_
doc_topics
# Out:
# array([[ 0.00986898,  0.0002773 ,  0.03561224, ..., -0.03690456,
#         -0.02559526, -0.02864922],
#        [ 0.00288644,  0.01226578,  0.12769907, ..., -0.01234438,
#         -0.01203736, -0.00448981],
#        [ 0.12340451,  0.01002103,  0.02025134, ..., -0.00783088,
#          0.02422855,  0.00483857],
#        ...,
#        [ 0.11219571, -0.03803499,  0.01743923, ...,  0.06894558,
#         -0.01892917, -0.01169217],
#        [ 0.0280353 , -0.0483438 ,  0.01626323, ...,  0.06461638,
#         -0.02805667, -0.02215552],
#        [ 0.01069581,  0.03026417, -0.02212655, ..., -0.07714946,
#          0.04130162, -0.00665551]])

# %%
year_topic = pd.DataFrame({'year': df.year, 'topic': doc_topics[:, topic_idx]})
year_topic.groupby('year').agg('mean')
# Out:
#          topic
# year
# 2007  0.025189
# 2008  0.016155
# 2009  0.019187
# 2010  0.013317
# 2011  0.010558
# 2012  0.016707
# 2013  0.015346
# 2014  0.014001
# 2015  0.009028
# 2016  0.007839
# 2017  0.006863

# %%
year_topic
# Out:
#       year     topic
# 0     2007  0.045137
# 1     2007 -0.023989
# 2     2007  0.024587
# 3     2007  0.008981
# 4     2007  0.006652
# ...    ...       ...
# 3915  2017 -0.020803
# 3916  2017  0.030219
# 3917  2017  0.017719
# 3918  2017 -0.015057
# 3919  2017  0.031341
#
# [3920 rows x 2 columns]
